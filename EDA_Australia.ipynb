# %% [markdown]
# <h1 align=center><font size="5"> EDA 2: Meteorological analysis of COVID-19 (Australia) </font></h1>

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ol>
#         <li><a href="#load_dataset">Loading the clean dataset</a></li>
#         <li><a href="#evaluation">Exploratory Data Analysis</a></li>
#         <li><a href="#practice">Conclusions</a></li>
#     </ol>
# </div>
# <br>
# <hr>

# %% [markdown]
# <h2 id="load_dataset">1. Loading the clean dataset</h2>

# %%
import pandas as pd

df=pd.read_csv("Meteorological_dataset_global.csv",  parse_dates=['Date'], index_col=['Date'])
df.head(50)
# Out:
#                                    State    Country   Capital  \
# Date
# 2020-01-22  Australian Capital Territory  Australia  Canberra
# 2020-01-22               New South Wales  Australia  Canberra
# 2020-01-22            Northern Territory  Australia  Canberra
# 2020-01-22                    Queensland  Australia  Canberra
# 2020-01-22               South Australia  Australia  Canberra
# 2020-01-22                      Tasmania  Australia  Canberra
# 2020-01-22                      Victoria  Australia  Canberra
# 2020-01-22             Western Australia  Australia  Canberra
# 2020-01-22                       Alberta     Canada    Ottawa
# 2020-01-22              British Columbia     Canada    Ottawa
# 2020-01-22                      Manitoba     Canada    Ottawa
# 2020-01-22                 New Brunswick     Canada    Ottawa
# 2020-01-22     Newfoundland and Labrador     Canada    Ottawa
# 2020-01-22                   Nova Scotia     Canada    Ottawa
# ...

# %% [markdown]
# <h2 id="load_dataset">2. Exploratory Data Analysis </h2>

# %% [markdown]
# <h1 align=center><font size="3"> Hypothesis </font></h1>

# %% [markdown]
# > *  The avg temp is highly positive correlated with number of cases
# > *  The humidity is highly positive correlated with number of cases
# > *  The wind speed is highly negative correlated with number of cases
# > *  The sun hour is highly positive correlated with number of cases

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h1 align=center><font size="3"> Queensland, Australia </font></h1>

# %%
df_Q=df.loc[df['State']=='Queensland']
df_Q.head(10)
# Out:
#                  State    Country   Capital       WHO Region      Lat  \
# Date
# 2020-01-22  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-23  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-24  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-25  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-26  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-27  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-28  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-29  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-30  Queensland  Australia  Canberra  Western Pacific -27.4698
# 2020-01-31  Queensland  Australia  Canberra  Western Pacific -27.4698
#
#                 Long  Confirmed  Deaths  Recovered  Active  mortality_rate  \
# Date
# 2020-01-22  153.0251          0       0          0       0             NaN
# ...

# %%
def line_plot(x,y,xlabel,ylabel,title):
    fig,ax=plt.subplots()
    ax.plot(x,y,color='r')
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    plt.show()

# %%
line_plot(df_Q.index,df_Q["Confirmed"],"Date","Cases","Confirmed cases vs Date")

# %%
line_plot(df_Q.index,df_Q["Temp / C"],"Date","Average Temperature","Average Temperature vs Date")

# %%
df_Q[["Confirmed","Temp / C"]].corr()
# Out:
#            Confirmed  Temp / C
# Confirmed   1.000000 -0.353413
# Temp / C   -0.353413  1.000000

# %%
sns.regplot(x="Confirmed", y="Temp / C", data=df_Q)
plt.ylim(0,)
# Out:
# (0, 41.26669426048565)

# %%
df_Q[["Confirmed","Humidity"]].corr()
# Out:
#            Confirmed  Humidity
# Confirmed   1.000000 -0.252669
# Humidity   -0.252669  1.000000

# %%
sns.regplot(x="Confirmed", y="Humidity", data=df_Q)
plt.ylim(0,)
# Out:
# (0, 99.06669426048565)

# %%
df_Q[["Confirmed","Wind Speed / KMPH"]].corr()
# Out:
#                    Confirmed  Wind Speed / KMPH
# Confirmed           1.000000           0.033725
# Wind Speed / KMPH   0.033725           1.000000

# %%
sns.regplot(x="Confirmed", y="Wind Speed / KMPH", data=df_Q)
plt.ylim(0,)
# Out:
# (0, 23.96669426048565)

# %%
df_Q[["Confirmed","Sun Hour"]].corr()
# Out:
#            Confirmed  Sun Hour
# Confirmed    1.00000  -0.43325
# Sun Hour    -0.43325   1.00000

# %%
sns.regplot(x="Confirmed", y="Sun Hour", data=df_Q)
plt.ylim(0,)
# Out:
# (0, 11.87669426048565)

# %% [markdown]
# <h1 align=center><font size="3"> Tasmania, Australia </font></h1>

# %%
df_T=df.loc[df['State']=='Tasmania']
df_T.head(10)
# Out:
#                State    Country   Capital       WHO Region      Lat      Long  \
# Date
# 2020-01-22  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-23  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-24  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-25  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-26  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-27  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-28  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-29  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-30  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
# 2020-01-31  Tasmania  Australia  Canberra  Western Pacific -42.8821  147.3272
#
#             Confirmed  Deaths  Recovered  Active  mortality_rate  Humidity  \
# Date
# ...

# %%
line_plot(df_T.index,df_T["Confirmed"],"Date","Cases","Confirmed cases vs Date")

# %%
line_plot(df_T.index,df_T["Temp / C"],"Date","Average Temperature","Average Temperature vs Date")

# %%
df_T[["Confirmed","Temp / C"]].corr()
# Out:
#            Confirmed  Temp / C
# Confirmed   1.000000 -0.293784
# Temp / C   -0.293784  1.000000

# %%
sns.regplot(x="Confirmed", y="Temp / C", data=df_T)
plt.ylim(0,)
# Out:
# (0, 41.26669426048565)

# %%
df_T[["Confirmed","Humidity"]].corr()
# Out:
#            Confirmed  Humidity
# Confirmed   1.000000  0.411998
# Humidity    0.411998  1.000000

# %%
sns.regplot(x="Confirmed", y="Humidity", data=df_T)
plt.ylim(0,)
# Out:
# (0, 99.06669426048565)

# %%
df_T[["Confirmed","Wind Speed / KMPH"]].corr()
# Out:
#                    Confirmed  Wind Speed / KMPH
# Confirmed           1.000000           0.014849
# Wind Speed / KMPH   0.014849           1.000000

# %%
sns.regplot(x="Confirmed", y="Wind Speed / KMPH", data=df_T)
plt.ylim(0,)
# Out:
# (0, 23.96669426048565)

# %%
df_T[["Confirmed","Sun Hour"]].corr()
# Out:
#            Confirmed  Sun Hour
# Confirmed   1.000000 -0.443355
# Sun Hour   -0.443355  1.000000

# %%
sns.regplot(x="Confirmed", y="Sun Hour", data=df_T)
plt.ylim(0,)
# Out:
# (0, 11.87669426048565)

# %% [markdown]
# <h1 align=center><font size="3"> New South Wales, Australia </font></h1>

# %%
df_N=df.loc[df['State']=='New South Wales']
df_N.head(10)
# Out:
#                       State    Country   Capital       WHO Region      Lat  \
# Date
# 2020-01-22  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-23  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-24  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-25  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-26  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-27  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-28  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-29  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-30  New South Wales  Australia  Canberra  Western Pacific -33.8688
# 2020-01-31  New South Wales  Australia  Canberra  Western Pacific -33.8688
#
#                 Long  Confirmed  Deaths  Recovered  Active  mortality_rate  \
# Date
# ...

# %%
line_plot(df_N.index,df_N["Confirmed"],"Date","Cases","Confirmed cases vs Date")

# %%
line_plot(df_N.index,df_N["Temp / C"],"Date","Average Temperature","Average Temperature vs Date")

# %%
df_N[["Confirmed","Temp / C"]].corr()
# Out:
#            Confirmed  Temp / C
# Confirmed   1.000000 -0.344498
# Temp / C   -0.344498  1.000000

# %%
sns.regplot(x="Confirmed", y="Temp / C", data=df_N)
plt.ylim(0,)
# Out:
# (0, 41.26669426048565)

# %%
df_N[["Confirmed","Humidity"]].corr()
# Out:
#            Confirmed  Humidity
# Confirmed   1.000000  0.424593
# Humidity    0.424593  1.000000

# %%
sns.regplot(x="Confirmed", y="Humidity", data=df_N)
plt.ylim(0,)
# Out:
# (0, 99.06669426048565)

# %%
df_N[["Confirmed","Wind Speed / KMPH"]].corr()
# Out:
#                    Confirmed  Wind Speed / KMPH
# Confirmed           1.000000           0.030496
# Wind Speed / KMPH   0.030496           1.000000

# %%
sns.regplot(x="Confirmed", y="Wind Speed / KMPH", data=df_N)
plt.ylim(0,)
# Out:
# (0, 23.96669426048565)

# %%
df_N[["Confirmed","Sun Hour"]].corr()
# Out:
#            Confirmed  Sun Hour
# Confirmed   1.000000 -0.441039
# Sun Hour   -0.441039  1.000000

# %%
sns.regplot(x="Confirmed", y="Sun Hour", data=df_N)
plt.ylim(0,)
# Out:
# (0, 11.87669426048565)

# %% [markdown]
# <h1 align=center><font size="3"> Victoria, Australia </font></h1

# %%
df_V=df.loc[df['State']=='Victoria']
df_V.head(10)
# Out:
#                State    Country   Capital       WHO Region      Lat      Long  \
# Date
# 2020-01-22  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-23  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-24  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-25  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-26  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-27  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-28  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-29  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-30  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
# 2020-01-31  Victoria  Australia  Canberra  Western Pacific -37.8136  144.9631
#
#             Confirmed  Deaths  Recovered  Active  mortality_rate  Humidity  \
# Date
# ...

# %%
line_plot(df_V.index,df_V["Confirmed"],"Date","Cases","Confirmed cases vs Date")

# %%
line_plot(df_V.index,df_V["Temp / C"],"Date","Average Temperature","Average Temperature vs Date")

# %%
df_V[["Confirmed","Temp / C"]].corr()
# Out:
#            Confirmed  Temp / C
# Confirmed   1.000000 -0.351165
# Temp / C   -0.351165  1.000000

# %%
sns.regplot(x="Confirmed", y="Temp / C", data=df_V)
plt.ylim(0,)
# Out:
# (0, 41.2675415661979)

# %%
df_V[["Confirmed","Humidity"]].corr()
# Out:
#            Confirmed  Humidity
# Confirmed   1.000000  0.419956
# Humidity    0.419956  1.000000

# %%
sns.regplot(x="Confirmed", y="Humidity", data=df_V)
plt.ylim(0,)
# Out:
# (0, 102.07548889758499)

# %%
df_V[["Confirmed","Wind Speed / KMPH"]].corr()
# Out:
#                    Confirmed  Wind Speed / KMPH
# Confirmed           1.000000           0.037719
# Wind Speed / KMPH   0.037719           1.000000

# %%
sns.regplot(x="Confirmed", y="Wind Speed / KMPH", data=df_V)
plt.ylim(0,)
# Out:
# (0, 23.96669426048565)

# %%
df_V[["Confirmed","Sun Hour"]].corr()
# Out:
#            Confirmed  Sun Hour
# Confirmed   1.000000 -0.447526
# Sun Hour   -0.447526  1.000000

# %%
sns.regplot(x="Confirmed", y="Sun Hour", data=df_V)
plt.ylim(0,)
# Out:
# (0, 11.925670246922712)

# %% [markdown]
# <h2 id="load_dataset">3. Conclusions </h2>

# %% [markdown]
# > *  The average temperature in the four most affected Australian provinces is only just mildly negatively correlated with the number of confirmed cases.
# > * The humidity percentage in these provinces yielded in majority of the cases a mild positive correlation.
# > * The wind speeds didn't correlate with the feature in focus at all.
# > * The sun hour metric proved to be mildly negatively correlated consistently among the four most affected provinces down under.
